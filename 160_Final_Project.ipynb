# %%
import pandas as pd
import requests
## Web scripting of Arizona Diamondbacks batting positions
url = "https://www.espn.com/mlb/team/stats/_/name/ari/season/2021/seasontype/2"
url_read = pd.read_html(url)
temp1 = pd.DataFrame(url_read[1])
temp2 = pd.DataFrame(url_read[0])
Arizona_Diamondbacks = temp2.join(temp1)
Arizona_Diamondbacks = Arizona_Diamondbacks.iloc[:-1 , :]
Arizona_Diamondbacks.insert(1, 'Team', 'Arizona Diamondbacks', True)

# %%
## Web scripting of Atlanta Braves batting positions
url2 = "https://www.espn.com/mlb/team/stats/_/name/atl/season/2021/seasontype/2"
url_read2 = pd.read_html(url2)
temp3 = pd.DataFrame(url_read2[1])
temp4 = pd.DataFrame(url_read2[0])
Atlanta_Braves = temp4.join(temp3)
Atlanta_Braves = Atlanta_Braves.iloc[:-1 , :]
Atlanta_Braves.insert(1, 'Team', 'Atlanta Braves', True)

# %%
## Web scripting of Baltimore Orioles batting positions
url3 = "https://www.espn.com/mlb/team/stats/_/name/bal/season/2021/seasontype/2"
url_read3 = pd.read_html(url3)
temp5 = pd.DataFrame(url_read3[1])
temp6 = pd.DataFrame(url_read3[0])
Baltimore_Orioles = temp6.join(temp5)
Baltimore_Orioles = Baltimore_Orioles.iloc[:-1 , :]
Baltimore_Orioles.insert(1, 'Team', 'Baltimore Orioles', True)

# %%
## Web scripting of Boston Red Sox batting positions
url4 = "https://www.espn.com/mlb/team/stats/_/name/bos/season/2021/seasontype/2"
url_read4 = pd.read_html(url4)
temp7 = pd.DataFrame(url_read4[1])
temp8 = pd.DataFrame(url_read4[0])
Boston_Red_Sox = temp8.join(temp7)
Boston_Red_Sox = Boston_Red_Sox.iloc[:-1 , :]
Boston_Red_Sox.insert(1, 'Team', 'Boston Red Sox', True)

# %%
## Web scripting of Chicago white Sox batting positions
url5 = "https://www.espn.com/mlb/team/stats/_/name/chc/season/2021/seasontype/2"
url_read5 = pd.read_html(url5)
temp9 = pd.DataFrame(url_read5[1])
temp10 = pd.DataFrame(url_read5[0])
Chicago_white_Sox = temp10.join(temp9)
Chicago_white_Sox = Chicago_white_Sox.iloc[:-1 , :]
Chicago_white_Sox.insert(1, 'Team', 'Chicago White Sox', True)

# %%
## Web scripting of Cincinnati Reds batting positions
url6 = "https://www.espn.com/mlb/team/stats/_/name/cin/season/2021/seasontype/2"
url_read6 = pd.read_html(url6)
temp11 = pd.DataFrame(url_read6[1])
temp12 = pd.DataFrame(url_read6[0])
Cincinnati_Reds = temp12.join(temp11)
Cincinnati_Reds = Cincinnati_Reds.iloc[:-1 , :]
Cincinnati_Reds.insert(1, 'Team', 'Cincinnati Reds', True)

# %%
## Web scripting of Cleveland Guardians batting positions
url7 = "https://www.espn.com/mlb/team/stats/_/name/cle/season/2021/seasontype/2"
url_read7 = pd.read_html(url7)
temp13 = pd.DataFrame(url_read7[1])
temp14 = pd.DataFrame(url_read7[0])
Cleaveland_Guardians = temp14.join(temp13)
Cleaveland_Guardians = Cleaveland_Guardians.iloc[:-1 , :]
Cleaveland_Guardians.insert(1, 'Team', 'Cleveland Guardians', True)

# %%
## Web scripting of Colorado Rockies positions
url8 = "https://www.espn.com/mlb/team/stats/_/name/col/season/2021/seasontype/2"
url_read8 = pd.read_html(url8)
temp15 = pd.DataFrame(url_read8[1])
temp16 = pd.DataFrame(url_read8[0])
Colorado_Rockies = temp16.join(temp15)
Colorado_Rockies = Colorado_Rockies.iloc[:-1 , :]
Colorado_Rockies.insert(1, 'Team', 'Colorado Rockies', True)

# %%
## Web scripting of Detroit Tigers positions
url9 = "https://www.espn.com/mlb/team/stats/_/name/det/season/2021/seasontype/2"
url_read9 = pd.read_html(url9)
temp17 = pd.DataFrame(url_read9[1])
temp18 = pd.DataFrame(url_read9[0])
Detroit_Tigers = temp18.join(temp17)
Detroit_Tigers = Detroit_Tigers.iloc[:-1 , :]
Detroit_Tigers.insert(1, 'Team', 'Detroit Tigers', True)

# %%
## Web scripting of Houston Astros positions
url10 = "https://www.espn.com/mlb/team/stats/_/name/hou/season/2021/seasontype/2"
url_read10 = pd.read_html(url10)
temp19 = pd.DataFrame(url_read10[1])
temp20 = pd.DataFrame(url_read10[0])
Houston_Astros = temp20.join(temp19)
Houston_Astros = Houston_Astros.iloc[:-1 , :]
Houston_Astros.insert(1, 'Team', 'Houston Astros', True)

# %%
## Web scripting of Kansas City Royals positions
url11 = "https://www.espn.com/mlb/team/stats/_/name/kc/season/2021/seasontype/2"
url_read11 = pd.read_html(url11)
temp21 = pd.DataFrame(url_read11[1])
temp22 = pd.DataFrame(url_read11[0])
Kansas_City_Royals = temp22.join(temp21)
Kansas_City_Royals = Kansas_City_Royals.iloc[:-1 , :]
Kansas_City_Royals.insert(1, 'Team', 'Kansas City Royals', True)

# %%
## Web scripting of Los Angeles Angels positions
url12 = "https://www.espn.com/mlb/team/stats/_/name/laa/season/2021/seasontype/2"
url_read12 = pd.read_html(url12)
temp23 = pd.DataFrame(url_read12[1])
temp24 = pd.DataFrame(url_read12[0])
Los_Angeles_Angels = temp24.join(temp23)
Los_Angeles_Angels = Los_Angeles_Angels.iloc[:-1 , :]
Los_Angeles_Angels.insert(1, 'Team', 'Los Angeles Angels', True)

# %%
## Web scripting of Los Angeles Dodgers positions
url13 = "https://www.espn.com/mlb/team/stats/_/name/lad/season/2021/seasontype/2"
url_read13 = pd.read_html(url13)
temp25 = pd.DataFrame(url_read13[1])
temp26 = pd.DataFrame(url_read13[0])
Los_Angeles_Dodgers = temp26.join(temp25)
Los_Angeles_Dodgers = Los_Angeles_Dodgers.iloc[:-1 , :]
Los_Angeles_Dodgers.insert(1, 'Team', 'Los Angeles Dodgers', True)

# %%
## Web scripting of Miami Marlins positions
url14 = "https://www.espn.com/mlb/team/stats/_/name/mia/season/2021/seasontype/2"
url_read14 = pd.read_html(url14)
temp27 = pd.DataFrame(url_read14[1])
temp28 = pd.DataFrame(url_read14[0])
Miami_Marlins = temp28.join(temp27)
Miami_Marlins = Miami_Marlins.iloc[:-1 , :]
Miami_Marlins.insert(1, 'Team', 'Miami Marlins', True)

# %%
## Web scripting of Milwaukee Brewers positions
url15 = "https://www.espn.com/mlb/team/stats/_/name/mil/season/2021/seasontype/2"
url_read15 = pd.read_html(url15)
temp29 = pd.DataFrame(url_read15[1])
temp30 = pd.DataFrame(url_read15[0])
Milwaukee_Brewers = temp30.join(temp29)
Milwaukee_Brewers = Milwaukee_Brewers.iloc[:-1 , :]
Milwaukee_Brewers.insert(1, 'Team', 'Milwaukee Brewers', True)

# %%
## Web scripting of Minnesota Twins positions
url16 = "https://www.espn.com/mlb/team/stats/_/name/min/season/2021/seasontype/2"
url_read16 = pd.read_html(url16)
temp31 = pd.DataFrame(url_read16[1])
temp32 = pd.DataFrame(url_read16[0])
Minnesota_Twins = temp32.join(temp31)
Minnesota_Twins = Minnesota_Twins.iloc[:-1 , :]
Minnesota_Twins.insert(1, 'Team', 'Minnesota Twins', True)

# %%
## Web scripting of New York Mets positions
url17 = "https://www.espn.com/mlb/team/stats/_/name/nym/season/2021/seasontype/2"
url_read17 = pd.read_html(url17)
temp33 = pd.DataFrame(url_read17[1])
temp34 = pd.DataFrame(url_read17[0])
New_York_Mets = temp34.join(temp33)
New_York_Mets = New_York_Mets.iloc[:-1 , :]
New_York_Mets.insert(1, 'Team', 'New York Mets', True)

# %%
## Web scripting of New York Yankees positions
url18 = "https://www.espn.com/mlb/team/stats/_/name/nyy/season/2021/seasontype/2"
url_read18 = pd.read_html(url18)
temp35 = pd.DataFrame(url_read18[1])
temp36 = pd.DataFrame(url_read18[0])
New_York_Yankees = temp36.join(temp35)
New_York_Yankees = New_York_Yankees.iloc[:-1 , :]
New_York_Yankees.insert(1, 'Team', 'New York Yankees', True)

# %%
## Web scripting of Oakland Athletics positions
url19 = "https://www.espn.com/mlb/team/stats/_/name/oak/season/2021/seasontype/2"
url_read19 = pd.read_html(url19)
temp37 = pd.DataFrame(url_read19[1])
temp38 = pd.DataFrame(url_read19[0])
Oakland_Athletics = temp38.join(temp37)
Oakland_Athletics = Oakland_Athletics.iloc[:-1 , :]
Oakland_Athletics.insert(1, 'Team', 'Oakland Athletics', True)

# %%
## Web scripting of Philadelphia Phillies positions
url20 = "https://www.espn.com/mlb/team/stats/_/name/phi/season/2021/seasontype/2"
url_read20 = pd.read_html(url20)
temp39 = pd.DataFrame(url_read20[1])
temp40 = pd.DataFrame(url_read20[0])
Philadelphia_Phillies = temp40.join(temp39)
Philadelphia_Phillies = Philadelphia_Phillies.iloc[:-1 , :]
Philadelphia_Phillies.insert(1, 'Team', 'Philadelphia Phillies', True)

# %%
## Web scripting of Pittsburgh Pirates positions
url21 = "https://www.espn.com/mlb/team/stats/_/name/pit/season/2021/seasontype/2"
url_read21 = pd.read_html(url21)
temp41 = pd.DataFrame(url_read21[1])
temp42 = pd.DataFrame(url_read21[0])
Pittsburgh_Pirates = temp42.join(temp41)
Pittsburgh_Pirates = Pittsburgh_Pirates.iloc[:-1 , :]
Pittsburgh_Pirates.insert(1, 'Team', 'Pittsburgh Pirates', True)

# %%
## Web scripting of San Diego Padres positions
url22 = "https://www.espn.com/mlb/team/stats/_/name/sd/season/2021/seasontype/2"
url_read22 = pd.read_html(url22)
temp43 = pd.DataFrame(url_read22[1])
temp44 = pd.DataFrame(url_read22[0])
San_Diego_Padres = temp44.join(temp43)
San_Diego_Padres = San_Diego_Padres.iloc[:-1 , :]
San_Diego_Padres.insert(1, 'Team', 'San Diego Padres', True)

# %%
## Web scripting of San Francisco Giants positions
url23 = "https://www.espn.com/mlb/team/stats/_/name/sf/season/2021/seasontype/2"
url_read23 = pd.read_html(url23)
temp45 = pd.DataFrame(url_read23[1])
temp46 = pd.DataFrame(url_read23[0])
San_Francisco_Giants = temp46.join(temp45)
San_Francisco_Giants = San_Francisco_Giants.iloc[:-1 , :]
San_Francisco_Giants.insert(1, 'Team', 'San Francisco Giants', True)

# %%
## Web scripting of Seattle Mariners positions
url24 = "https://www.espn.com/mlb/team/stats/_/name/sea/season/2021/seasontype/2"
url_read24 = pd.read_html(url24)
temp47 = pd.DataFrame(url_read24[1])
temp48 = pd.DataFrame(url_read24[0])
Seattle_Mariners = temp48.join(temp47)
Seattle_Mariners = Seattle_Mariners.iloc[:-1 , :]
Seattle_Mariners.insert(1, 'Team', 'Seattle Mariners', True)

# %%
## Web scripting of St. Louis Cardinals positions
url25 = "https://www.espn.com/mlb/team/stats/_/name/stl/season/2021/seasontype/2"
url_read25 = pd.read_html(url25)
temp49 = pd.DataFrame(url_read25[1])
temp50 = pd.DataFrame(url_read25[0])
StLouis_Cardinals = temp50.join(temp49)
StLouis_Cardinals = StLouis_Cardinals.iloc[:-1 , :]
StLouis_Cardinals.insert(1, 'Team', 'St. Louis Cardinals', True)

# %%
## Web scripting of Tempa Bay Rays Cardinals positions
url26 = "https://www.espn.com/mlb/team/stats/_/name/tb/season/2021/seasontype/2"
url_read26 = pd.read_html(url26)
temp51 = pd.DataFrame(url_read26[1])
temp52 = pd.DataFrame(url_read26[0])
Tempa_Bay_Rays = temp52.join(temp51)
Tempa_Bay_Rays = Tempa_Bay_Rays.iloc[:-1 , :]
Tempa_Bay_Rays.insert(1, 'Team', 'Tempa Bay Rays', True)

# %%
## Web scripting of Texas Rangers Cardinals positions
url27 = "https://www.espn.com/mlb/team/stats/_/name/tex/season/2021/seasontype/2"
url_read27 = pd.read_html(url27)
temp53 = pd.DataFrame(url_read27[1])
temp54 = pd.DataFrame(url_read27[0])
Texas_Rangers = temp54.join(temp53)
Texas_Rangers = Texas_Rangers.iloc[:-1 , :]
Texas_Rangers.insert(1, 'Team', 'Texas Rangers', True)

# %%
## Web scripting of Toronto Blue Jays Cardinals positions
url28 = "https://www.espn.com/mlb/team/stats/_/name/tor/season/2021/seasontype/2"
url_read28 = pd.read_html(url28)
temp55 = pd.DataFrame(url_read28[1])
temp56 = pd.DataFrame(url_read28[0])
Toronto_Blue_Jays = temp56.join(temp55)
Toronto_Blue_Jays = Toronto_Blue_Jays.iloc[:-1 , :]
Toronto_Blue_Jays.insert(1, 'Team', 'Toronto Blue Jays', True)

# %%
## Web scripting of Washington Nationals positions
url29 = "https://www.espn.com/mlb/team/stats/_/name/wsh/season/2021/seasontype/2"
url_read29 = pd.read_html(url29)
temp57 = pd.DataFrame(url_read29[1])
temp58 = pd.DataFrame(url_read29[0])
Washington_Nationals = temp58.join(temp57)
Washington_Nationals = Washington_Nationals.iloc[:-1 , :]
Washington_Nationals.insert(1, 'Team', 'Washington Nationals', True)

# %%
## Web scripting of Chicago Cubs positions
url30 = "https://www.espn.com/mlb/team/stats/_/name/chc/season/2021/seasontype/2"
url_read30 = pd.read_html(url30)
temp59 = pd.DataFrame(url_read30[1])
temp60 = pd.DataFrame(url_read30[0])
Chicago_Cubs = temp60.join(temp59)
Chicago_Cubs = Chicago_Cubs.iloc[:-1 , :]
Chicago_Cubs.insert(1, 'Team', 'Chicago Cubs', True)

# %%
batting = pd.concat([Arizona_Diamondbacks, Atlanta_Braves, Baltimore_Orioles,Boston_Red_Sox,Chicago_white_Sox,Chicago_Cubs,Cincinnati_Reds,Cleaveland_Guardians,Colorado_Rockies, Detroit_Tigers,Houston_Astros,Kansas_City_Royals,Los_Angeles_Angels,Los_Angeles_Dodgers,Miami_Marlins,Milwaukee_Brewers,Minnesota_Twins,New_York_Mets,New_York_Yankees,Oakland_Athletics, Philadelphia_Phillies,Pittsburgh_Pirates,San_Diego_Padres,San_Francisco_Giants,Seattle_Mariners,StLouis_Cardinals,Tempa_Bay_Rays,Texas_Rangers,Toronto_Blue_Jays,Washington_Nationals], ignore_index = True, sort = False)
batting
# Out:
#                      Name                  Team   GP   AB   R    H  2B  3B  \
# 0          Pavin Smith RF  Arizona Diamondbacks  145  498  68  133  27   4
# 1        David Peralta LF  Arizona Diamondbacks  150  487  57  126  30   8
# 2           Josh Rojas 3B  Arizona Diamondbacks  139  484  69  128  32   3
# 3           Nick Ahmed SS  Arizona Diamondbacks  129  434  46   96  30   3
# 4     Christian Walker 1B  Arizona Diamondbacks  115  401  55   98  23   1
# ...                   ...                   ...  ...  ...  ..  ...  ..  ..
# 1189       Cody Wilson CF  Washington Nationals    1    1   0    0   0   0
# 1190       Javy Guerra RP  Washington Nationals    6    1   0    0   0   0
# 1191       Ryne Harper RP  Washington Nationals   32    1   0    0   0   0
# 1192    Patrick Murphy RP  Washington Nationals   17    1   0    0   0   0
# 1193      Wander Suero RP  Washington Nationals   43    1   0    0   0   0
#
#       HR  RBI   TB  BB   SO  SB    AVG    OBP    SLG    OPS  WAR
# ...

# %%
batting['AVG'].median()
# Out:
# 0.1975

# %%
batting['GP'].median()
# Out:
# 31.0

# %%
batting = batting[batting['GP'] >= 50]
batting
# Out:
#                      Name                  Team   GP   AB   R    H  2B  3B  \
# 0          Pavin Smith RF  Arizona Diamondbacks  145  498  68  133  27   4
# 1        David Peralta LF  Arizona Diamondbacks  150  487  57  126  30   8
# 2           Josh Rojas 3B  Arizona Diamondbacks  139  484  69  128  32   3
# 3           Nick Ahmed SS  Arizona Diamondbacks  129  434  46   96  30   3
# 4     Christian Walker 1B  Arizona Diamondbacks  115  401  55   98  23   1
# ...                   ...                   ...  ...  ...  ..  ...  ..  ..
# 1158        Yan Gomes C *  Washington Nationals   63  218  30   59  11   1
# 1159    Carter Kieboom SS  Washington Nationals   62  217  26   45   6   0
# 1160  Andrew Stevenson CF  Washington Nationals  109  192  22   44   6   0
# 1163     Gerardo Parra CF  Washington Nationals   53   97  13   23   5   0
# 1187          Sam Clay RP  Washington Nationals   54    2   0    0   0   0
#
#       HR  RBI   TB  BB   SO  SB    AVG    OBP    SLG    OPS  WAR
# ...

# %%
batting.isnull().sum()
## There is no missing value in the whole dataset and the data's already been cleaned
# Out:
# Name    0
# Team    0
# GP      0
# AB      0
# R       0
# H       0
# 2B      0
# 3B      0
# HR      0
# RBI     0
# TB      0
# BB      0
# SO      0
# SB      0
# AVG     0
# OBP     0
# SLG     0
# OPS     0
# WAR     0
# dtype: int64

# %%
batting.describe()
# Out:
#                GP          AB           R           H          2B          3B  \
# count  598.000000  598.000000  598.000000  598.000000  598.000000  598.000000
# mean    85.764214  253.881271   35.162207   63.153846   12.568562    1.076923
# std     39.976621  177.247343   28.683663   48.744159   10.313567    1.456494
# min     31.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     51.000000  112.250000   13.000000   24.000000    4.000000    0.000000
# 50%     77.500000  224.000000   28.000000   53.000000   10.000000    1.000000
# 75%    121.000000  387.000000   54.000000   96.000000   20.000000    2.000000
# max    162.000000  664.000000  123.000000  191.000000   42.000000    8.000000
#
#                HR         RBI          TB          BB          SO          SB  \
# count  598.000000  598.000000  598.000000  598.000000  598.000000  598.000000
# mean     9.717391   33.792642  107.028428   25.081940   64.270903    3.642140
# ...

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
sm.qqplot(Arizona_Diamondbacks['AVG'],fit=True,line="45")
plt.show()

# %%
import seaborn as sns
sns.displot(Arizona_Diamondbacks, x="AVG")

# %%
sm.qqplot(Atlanta_Braves['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Atlanta_Braves, x="AVG")

# %%
sm.qqplot(Baltimore_Orioles['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Baltimore_Orioles, x="AVG")

# %%
sm.qqplot(Boston_Red_Sox['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Boston_Red_Sox, x="AVG")

# %%
sm.qqplot(Chicago_white_Sox['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Chicago_white_Sox, x="AVG")

# %%
sm.qqplot(Cincinnati_Reds['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Cincinnati_Reds, x="AVG")

# %%
sm.qqplot(Cleaveland_Guardians['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Cleaveland_Guardians, x="AVG")

# %%
sm.qqplot(Colorado_Rockies['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Colorado_Rockies, x="AVG")

# %%
sm.qqplot(Detroit_Tigers['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Detroit_Tigers, x="AVG")

# %%
sm.qqplot(Houston_Astros['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Houston_Astros, x="AVG")

# %%
sm.qqplot(Kansas_City_Royals['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Kansas_City_Royals, x="AVG")

# %%
sm.qqplot(Los_Angeles_Angels['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Los_Angeles_Angels, x="AVG")

# %%
sm.qqplot(Los_Angeles_Dodgers['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Los_Angeles_Dodgers, x="AVG")

# %%
sm.qqplot(Miami_Marlins['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Miami_Marlins, x="AVG")

# %%
sm.qqplot(Milwaukee_Brewers['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Milwaukee_Brewers, x="AVG")

# %%
sm.qqplot(Minnesota_Twins['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Minnesota_Twins, x="AVG")

# %%
sm.qqplot(New_York_Mets['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(New_York_Mets, x="AVG")

# %%
sm.qqplot(New_York_Yankees['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(New_York_Yankees, x="AVG")

# %%
sm.qqplot(Oakland_Athletics['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Oakland_Athletics, x="AVG")

# %%
sm.qqplot(Philadelphia_Phillies['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Philadelphia_Phillies, x="AVG")

# %%
sm.qqplot(Pittsburgh_Pirates['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Pittsburgh_Pirates, x="AVG")

# %%
sm.qqplot(San_Diego_Padres['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(San_Diego_Padres, x="AVG")

# %%
sm.qqplot(San_Francisco_Giants['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(San_Francisco_Giants, x="AVG")

# %%
sm.qqplot(Seattle_Mariners['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Seattle_Mariners, x="AVG")

# %%
sm.qqplot(StLouis_Cardinals['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(StLouis_Cardinals, x="AVG")

# %%
sm.qqplot(Tempa_Bay_Rays['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Tempa_Bay_Rays, x="AVG")

# %%
sm.qqplot(Texas_Rangers['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Texas_Rangers, x="AVG")

# %%
sm.qqplot(Toronto_Blue_Jays['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Toronto_Blue_Jays, x="AVG")

# %%
sm.qqplot(Washington_Nationals['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Washington_Nationals, x="AVG")

# %%
sm.qqplot(Chicago_Cubs['AVG'],fit=True,line="45")
plt.show()

# %%
sns.displot(Chicago_Cubs, x="AVG")

# %%
sns.displot(data=batting, x='AVG', hue='Team', kind='kde', fill=True)

# %%
_ = batting.hist(figsize=(16,16), grid=False)

# %%
import seaborn as sns
sns.set(rc = {'figure.figsize':(15,8)})
cor = batting.corr()
sns.heatmap(batting.corr(), annot = True, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
## Pearson's Correlation test (Fature Selection)
corr = batting.corr()["AVG"].sort_values(ascending=False)[1:]

# absolute for positive values
abs_corr = abs(corr)

# random threshold for features to keep
relevant_features = abs_corr[abs_corr>0.4]
relevant_features
# Out:
# OPS    0.919726
# OBP    0.918669
# SLG    0.862973
# H      0.525066
# TB     0.486347
# 2B     0.481506
# AB     0.478595
# R      0.466137
# RBI    0.431011
# Name: AVG, dtype: float64

# %%
batting.drop(columns = ["HR","WAR", "3B","SB"],inplace=True)
batting
# Out:
# /Users/louiseli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                      Name                  Team   GP   AB   R    H  2B  RBI  \
# 0          Pavin Smith RF  Arizona Diamondbacks  145  498  68  133  27   49
# 1        David Peralta LF  Arizona Diamondbacks  150  487  57  126  30   63
# 2           Josh Rojas 3B  Arizona Diamondbacks  139  484  69  128  32   44
# 3           Nick Ahmed SS  Arizona Diamondbacks  129  434  46   96  30   38
# 4     Christian Walker 1B  Arizona Diamondbacks  115  401  55   98  23   46
# ...                   ...                   ...  ...  ...  ..  ...  ..  ...
# 1158        Yan Gomes C *  Washington Nationals   63  218  30   59  11   35
# ...

# %%
import seaborn as sns
sns.set(rc = {'figure.figsize':(15,8)})
cor = batting.corr()
sns.heatmap(batting.corr(), annot = True, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
batting.drop(columns = ["Name","Team"],inplace=True)
batting
# Out:
# /Users/louiseli/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#        GP   AB   R    H  2B  RBI   TB  BB   SO    AVG    OBP    SLG    OPS
# 0     145  498  68  133  27   49  201  42  106  0.267  0.328  0.404  0.732
# 1     150  487  57  126  30   63  196  46   92  0.259  0.325  0.402  0.728
# 2     139  484  69  128  32   44  199  58  137  0.264  0.341  0.411  0.752
# 3     129  434  46   96  30   38  147  34  104  0.221  0.280  0.339  0.619
# 4     115  401  55   98  23   46  153  38  106  0.244  0.315  0.382  0.696
# ...   ...  ...  ..  ...  ..  ...  ...  ..  ...    ...    ...    ...    ...
# 1158   63  218  30   59  11   35   99  13   47  0.271  0.323  0.454  0.778
# ...

# %% [markdown]
# ## Random Forest

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error

X_train, X_test, y_train, y_test = train_test_split(batting.loc[:, batting.columns != 'AVG'], batting['AVG'], test_size=0.2, random_state=0)
# Feature Scaling
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

regressor = RandomForestRegressor(n_estimators=20, random_state=0)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)

# %%
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 0.011166483516483517
# Mean Squared Error: 0.00025969585164835167

# %%
forest = RandomForestRegressor(300, random_state=42)
forest.fit(X_train, y_train)
y_pred = forest.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print('Testing MSE:', mse)
acc = forest.score(X_test, y_test)
print('Accuracy:', acc)
# Out:
# Testing MSE: 0.00030331454004883936
# Accuracy: 0.9504974792340616

# %%
from sklearn.tree import plot_tree

fig = plt.figure(figsize=(15, 10))
_ = plot_tree(regressor.estimators_[0], 
          feature_names = batting.columns,
          class_names=['AVG'], 
          filled=True, impurity=True, 
          rounded=True)

# %% [markdown]
# ### Predict AVG Ranking

# %%
y_pred = forest.predict(batting.loc[:, batting.columns != 'AVG'])
DT_pred = batting.copy()
DT_pred = DT_pred.drop('AVG',axis=1)
DT_pred.insert(12, "Predicted AVG", y_pred, True)

# %%
sorted_pred = DT_pred.sort_values(by = 'Predicted AVG', ascending=True)
sorted_pred
sorted_pred.tail(10)
# Out:
#        GP   AB    R    H  2B  RBI   TB   BB   SO    OBP    SLG    OPS  \
# 503    52  207   41   70  17   28  117   15   33  0.385  0.565  0.950
# 939    97  325   65   89  14   59  194   48  103  0.378  0.597  0.975
# 270   110  423   77  129  32   71  235   53   75  0.394  0.556  0.949
# 162    56  222   42   76  19   40  136   16   36  0.389  0.613  1.002
# 219    56  222   42   76  19   40  136   16   36  0.389  0.613  1.002
# 1118  161  604  123  188  29  111  363   86  110  0.401  0.601  1.002
# 50     82  297   72   84  19   52  177   49   85  0.394  0.596  0.990
# 1147  151  502  111  157  20   95  268  145   93  0.465  0.534  0.999
# 800   141  488  101  151  42   84  300  100  134  0.429  0.615  1.044
# 369    64    1    1    1   0    0    1    0    0  1.000  1.000  2.000
#
#       Predicted AVG
# 503        0.275420
# 939        0.275437
# 270        0.275510
# 162        0.275520
# 219        0.275520
# 1118       0.275680
# 50         0.275763
# 1147       0.275790
# ...

# %%
batting_verify = pd.concat([Arizona_Diamondbacks, Atlanta_Braves, Baltimore_Orioles,Boston_Red_Sox,Chicago_white_Sox,Chicago_Cubs,Cincinnati_Reds,Cleaveland_Guardians,Colorado_Rockies, Detroit_Tigers,Houston_Astros,Kansas_City_Royals,Los_Angeles_Angels,Los_Angeles_Dodgers,Miami_Marlins,Milwaukee_Brewers,Minnesota_Twins,New_York_Mets,New_York_Yankees,Oakland_Athletics, Philadelphia_Phillies,Pittsburgh_Pirates,San_Diego_Padres,San_Francisco_Giants,Seattle_Mariners,StLouis_Cardinals,Tempa_Bay_Rays,Texas_Rangers,Toronto_Blue_Jays,Washington_Nationals], ignore_index = True, sort = False)

# %%
list_pred = [369,800,1147,50,1118,219,162,270,939,503]
for i in range(0,len(list_pred)):
    if i == 0:
        print("1st batter name:{}, Team:{},True AVG:{}".format(batting_verify.iloc[list_pred[i],0],
                                                                           batting_verify.iloc[list_pred[i],1],
                                                                            batting_verify.iloc[list_pred[i],14]
                                                                          ))
    elif i ==1:
        print("2nd batter name:{}, Team:{},True AVG:{}".format(batting_verify.iloc[list_pred[i],0],
                                                                           batting_verify.iloc[list_pred[i],1],
                                                                            batting_verify.iloc[list_pred[i],14]))
    elif i==2:
        print("3rd batter name:{}, Team:{},True AVG:{}".format(batting_verify.iloc[list_pred[i],0],
                                                                           batting_verify.iloc[list_pred[i],1],
                                                                            batting_verify.iloc[list_pred[i],14]))
    else:
        print("{}th batter name:{}, Team:{},True AVG:{}".format(i+1,batting_verify.iloc[list_pred[i],0],
                                                                           batting_verify.iloc[list_pred[i],1],
                                                                            batting_verify.iloc[list_pred[i],14]))
# Out:
# 1st batter name:Daniel Bard RP, Team:Colorado Rockies,True AVG:1.0
# 2nd batter name:Bryce Harper DH, Team:Philadelphia Phillies,True AVG:0.309
# 3rd batter name:Juan Soto LF, Team:Washington Nationals,True AVG:0.313
# 4th batter name:Ronald Acuna Jr. RF, Team:Atlanta Braves,True AVG:0.283
# 5th batter name:Vladimir Guerrero Jr. 1B, Team:Toronto Blue Jays,True AVG:0.311
# 6th batter name:Frank Schwindel 1B *, Team:Chicago Cubs,True AVG:0.342
# 7th batter name:Frank Schwindel 1B *, Team:Chicago White Sox,True AVG:0.342
# 8th batter name:Jesse Winker RF, Team:Cincinnati Reds,True AVG:0.305
# 9th batter name:Brandon Belt 1B, Team:San Francisco Giants,True AVG:0.274
# 10th batter name:Trea Turner SS *, Team:Los Angeles Dodgers,True AVG:0.338

# %% [markdown]
# ## XGboost

# %%
from xgboost import XGBRegressor


xgb = XGBRegressor(max_depth=3, learning_rate=1, n_estimators=100, random_state = 42)
xgb.fit(X_train, y_train)
y_pred = xgb.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print('Testing MSE:', mse)
acc = xgb.score(X_test, y_test)
print('Accuracy:', acc)
# Out:
# Testing MSE: 0.0005081641096038598
# Accuracy: 0.9170649571098068

# %% [markdown]
# ### Predicted AVG Ranking

# %%
batting_sc = batting.copy()
batting_sc = batting_sc.drop('AVG',axis=1)
y_pred = xgb.predict(sc.fit_transform(batting_sc))
XGB_pred = batting.copy()
XGB_pred = XGB_pred.drop('AVG',axis=1)
XGB_pred.insert(12, "Predicted AVG", y_pred, True)
sorted_pred = XGB_pred.sort_values(by = 'Predicted AVG', ascending=True)
sorted_pred
sorted_pred.tail(10)
# Out:
#        GP   AB    R    H  2B  RBI   TB   BB  SO    OBP    SLG    OPS  \
# 270   110  423   77  129  32   71  235   53  75  0.394  0.556  0.949
# 1149   96  388   66  125  17   49  202   26  77  0.369  0.521  0.890
# 406   143  530   83  169  31   81  245   59  68  0.383  0.462  0.846
# 1147  151  502  111  157  20   95  268  145  93  0.465  0.534  0.999
# 951    52  121   19   33   4   22   58    9  23  0.333  0.479  0.813
# 552    64  233   52   71  11   25  105   32  57  0.405  0.451  0.856
# 776    56  234   37   73  16   30  108   11  42  0.355  0.462  0.816
# 841    98  386   58  125  28   32  173   35  46  0.388  0.448  0.836
# 219    56  222   42   76  19   40  136   16  36  0.389  0.613  1.002
# 162    56  222   42   76  19   40  136   16  36  0.389  0.613  1.002
#
#       Predicted AVG
# 270        0.310711
# 1149       0.313053
# 406        0.314484
# 1147       0.315312
# 951        0.319079
# 552        0.320062
# 776        0.323557
# 841        0.325386
# ...

# %%
list_pred = [162,219,841,776,552,951,1147,406,1149,270]
for i in range(0,len(list_pred)):
    if i == 0:
        print("1st batter name:{}, Team:{},True AVG:{}".format(batting_verify.iloc[list_pred[i],0],
                                                                           batting_verify.iloc[list_pred[i],1],
                                                                            batting_verify.iloc[list_pred[i],14]
                                                                          ))
    elif i ==1:
        print("2nd batter name:{}, Team:{},True AVG:{}".format(batting_verify.iloc[list_pred[i],0],
                                                                           batting_verify.iloc[list_pred[i],1],
                                                                            batting_verify.iloc[list_pred[i],14]))
    elif i==2:
        print("3rd batter name:{}, Team:{},True AVG:{}".format(batting_verify.iloc[list_pred[i],0],
                                                                           batting_verify.iloc[list_pred[i],1],
                                                                            batting_verify.iloc[list_pred[i],14]))
    else:
        print("{}th batter name:{}, Team:{},True AVG:{}".format(i+1,batting_verify.iloc[list_pred[i],0],
                                                                           batting_verify.iloc[list_pred[i],1],
                                                                            batting_verify.iloc[list_pred[i],14]))
# Out:
# 1st batter name:Frank Schwindel 1B *, Team:Chicago White Sox,True AVG:0.342
# 2nd batter name:Frank Schwindel 1B *, Team:Chicago Cubs,True AVG:0.342
# 3rd batter name:Adam Frazier 2B *, Team:Pittsburgh Pirates,True AVG:0.324
# 4th batter name:Starling Marte RF *, Team:Oakland Athletics,True AVG:0.312
# 5th batter name:Starling Marte RF *, Team:Miami Marlins,True AVG:0.305
# 6th batter name:Thairo Estrada SS, Team:San Francisco Giants,True AVG:0.273
# 7th batter name:Juan Soto LF, Team:Washington Nationals,True AVG:0.313
# 8th batter name:Yuli Gurriel 1B, Team:Houston Astros,True AVG:0.319
# 9th batter name:Trea Turner SS *, Team:Washington Nationals,True AVG:0.322
# 10th batter name:Jesse Winker RF, Team:Cincinnati Reds,True AVG:0.305

# %% [markdown]
# ## KNN

# %%
import numpy as np
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

train, test = train_test_split(batting, test_size=0.2, random_state=2)

X_train, y_train = train.copy().drop(columns=['AVG']), train['AVG']
X_test, y_test = test.copy().drop(columns=['AVG']), test['AVG']

# Create KNN classifier
knn = KNeighborsRegressor(n_neighbors = 3)
# Fit the classifier to the data
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print('Testing MSE:', mse)
acc = knn.score(X_test, y_test)
print('Accuracy:', acc)

#create a new KNN model
knn_cv = KNeighborsRegressor(n_neighbors=3)

#Cross validation KNN model
cv_scores = cross_val_score(knn_cv, batting.loc[:, batting.columns != 'AVG'], batting['AVG'], cv=5)
#print each accuracy and average them
print(cv_scores)
print('cv_scores mean:{}'.format(np.mean(cv_scores)))
# Out:
# Testing MSE: 0.00043228571428571426
# Accuracy: 0.9016700304382045
# [ 0.77443512 -0.58103085  0.66519657  0.91420012  0.88899676]
# cv_scores mean:0.5323595455891785

# %%
error = []

for i in range(1, 20):
    knn = KNeighborsRegressor(n_neighbors=i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    error.append(np.mean(pred_i != y_test))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.plot(range(1, 20), error, color='green', linestyle='dashed', marker='o',
         markerfacecolor='yellow', markersize=15)
plt.title('Error vs K Value')
plt.xlabel('K Value')
plt.ylabel('Mean Error')
# Out:
# Text(0, 0.5, 'Mean Error')

# %% [markdown]
# ### Predicted AVG Ranking

# %%
y_pred = knn.predict(batting.loc[:, batting.columns != 'AVG'])
KNN_pred = batting.copy()
KNN_pred = KNN_pred.drop('AVG',axis=1)
KNN_pred.insert(12, "Predicted AVG", y_pred, True)
sorted_pred = KNN_pred.sort_values(by = 'Predicted AVG', ascending=True)
sorted_pred
sorted_pred.tail(10)
# Out:
#        GP   AB    R    H  2B  RBI   TB   BB   SO    OBP    SLG    OPS  \
# 90    159  602   91  175  37   59  312   59  125  0.360  0.518  0.878
# 800   141  488  101  151  42   84  300  100  134  0.429  0.615  1.044
# 839   159  559   93  169  35   90  292   75  119  0.390  0.522  0.912
# 403   146  602  117  167  32   83  294   66   91  0.350  0.488  0.838
# 1118  161  604  123  188  29  111  363   86  110  0.401  0.601  1.002
# 406   143  530   83  169  31   81  245   59   68  0.383  0.462  0.846
# 46    159  600  120  180  25   83  302   85  107  0.393  0.503  0.896
# 767   156  565  101  153  35  111  305   88  113  0.371  0.540  0.911
# 306   152  552  111  147  32  103  297   72   87  0.355  0.538  0.893
# 891   153  564   92  157  31  106  276   63  102  0.347  0.489  0.836
#
#       Predicted AVG
# 90         0.277316
# 800        0.278842
# 839        0.278947
# 403        0.279632
# 1118       0.279684
# 406        0.280053
# 46         0.281105
# 767        0.281421
# ...

# %%
list_pred = [891,306,767,46,406,1118,403,839,800,90]
for i in range(0,len(list_pred)):
    if i == 0:
        print("1st batter name:{}, Team:{},True AVG:{}".format(batting_verify.iloc[list_pred[i],0],
                                                                           batting_verify.iloc[list_pred[i],1],
                                                                            batting_verify.iloc[list_pred[i],14]
                                                                          ))
    elif i ==1:
        print("2nd batter name:{}, Team:{},True AVG:{}".format(batting_verify.iloc[list_pred[i],0],
                                                                           batting_verify.iloc[list_pred[i],1],
                                                                            batting_verify.iloc[list_pred[i],14]))
    elif i==2:
        print("3rd batter name:{}, Team:{},True AVG:{}".format(batting_verify.iloc[list_pred[i],0],
                                                                           batting_verify.iloc[list_pred[i],1],
                                                                            batting_verify.iloc[list_pred[i],14]))
    else:
        print("{}th batter name:{}, Team:{},True AVG:{}".format(i+1,batting_verify.iloc[list_pred[i],0],
                                                                           batting_verify.iloc[list_pred[i],1],
                                                                            batting_verify.iloc[list_pred[i],14]))
# Out:
# 1st batter name:Manny Machado 3B, Team:San Diego Padres,True AVG:0.278
# 2nd batter name:Jose Ramirez 3B, Team:Cleveland Guardians,True AVG:0.266
# 3rd batter name:Matt Olson 1B, Team:Oakland Athletics,True AVG:0.271
# 4th batter name:Freddie Freeman 1B, Team:Atlanta Braves,True AVG:0.3
# 5th batter name:Yuli Gurriel 1B, Team:Houston Astros,True AVG:0.319
# 6th batter name:Vladimir Guerrero Jr. 1B, Team:Toronto Blue Jays,True AVG:0.311
# 7th batter name:Jose Altuve 2B, Team:Houston Astros,True AVG:0.277
# 8th batter name:Bryan Reynolds LF, Team:Pittsburgh Pirates,True AVG:0.302
# 9th batter name:Bryce Harper DH, Team:Philadelphia Phillies,True AVG:0.309
# 10th batter name:Cedric Mullins CF, Team:Baltimore Orioles,True AVG:0.291
